# %% [markdown]
# <a href="https://colab.research.google.com/github/MRosinskiGit/Colab/blob/main/jupiter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import Sequential
from keras.layers import Dense
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

df = pd.read_csv('textures_data.csv', sep=',')
data=df.to_numpy()

X=data[:,:-1].astype('float')
y=data[:,-1]

label_encoder = LabelEncoder()
integer_encoded=label_encoder.fit_transform(y)
# Out:
#   File "<ipython-input-5-57aca2419d7f>", line 1
#     git remote add origin https://github.com/MRosinskiGit/Colab.git
#              ^
# SyntaxError: invalid syntax

# %%
onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded=integer_encoded.reshape(len(integer_encoded), 1)
onehot_encoded = onehot_encoder.fit_transform(integer_encoded)

X_train, X_test, y_train, y_test = train_test_split(X, onehot_encoded, test_size=0.3)

model = Sequential()
model.add(Dense(10, input_dim=72, activation='sigmoid'))
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy', 
              optimizer='sgd', metrics=['accuracy'])

model.summary()

model.fit(X_train, y_train, epochs=100, batch_size=10, shuffle=True)

y_pred = model.predict(X_test)
y_pred_int = np.argmax(y_pred, axis=1)
y_test_int = np.argmax(y_test,axis=1)
cm=confusion_matrix(y_test_int, y_pred_int)
print(cm)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 10)                730
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 33
# ...
# Total params: 763
# Trainable params: 763
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 21/21 [==============================] - 0s 2ms/step - loss: 1.1934 - accuracy: 0.4492
# Epoch 2/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9287 - accuracy: 0.7091
# Epoch 3/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8282 - accuracy: 1.0000
# Epoch 4/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7714 - accuracy: 1.0000
# Epoch 5/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7210 - accuracy: 1.0000
# ...
